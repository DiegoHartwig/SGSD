# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoHartwig/SGSD/blob/master/CNN_Redes_Neurais_Convolucionais_Classificacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Implementando classificação de imagens com arquitetura CNN (Convolutional Neural Network)
#
# Diego Hartwig - 2024

# %% [markdown]
# ## Importações das bibliotecas

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## Carregando a base de dados

# %%
cifar10 = tf.keras.datasets.cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 19s 0us/step

# %% [markdown]
# ## Normalização da base de dados

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

y_train, y_test = y_train.flatten(), y_test.flatten()

print("x_train.shape", x_train.shape)
print("x_test.shape", x_test.shape)
print("y_train.shape", y_train.shape)
print("y_test.shape", y_test.shape)
# Out:
# x_train.shape (50000, 32, 32, 3)
# x_test.shape (10000, 32, 32, 3)
# y_train.shape (50000,)
# y_test.shape (10000,)

# %% [markdown]
# ## Criando a Rede

# %%
K = len(set(y_train))

i = Input(shape=x_train[0].shape)
x = Conv2D(32, (3, 3), strides=2, activation='relu')(i)
x = Conv2D(64, (3, 3), strides=2, activation='relu')(x)
x = Conv2D(128, (3, 3), strides=2, activation='relu')(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(K, activation='softmax')(x)

model = Model(i, x)

# %% [markdown]
# ## Exibindo os dados

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 15, 15, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)          18496
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         73856
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dropout (Dropout)           (None, 1152)              0
#
#  dense (Dense)               (None, 1024)              1180672
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 1284170 (4.90 MB)
# Trainable params: 1284170 (4.90 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Compilação e Treinamento do modelo

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

r = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=15)
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 14s 5ms/step - loss: 1.5848 - accuracy: 0.4185 - val_loss: 1.2944 - val_accuracy: 0.5316
# Epoch 2/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.2962 - accuracy: 0.5329 - val_loss: 1.1289 - val_accuracy: 0.5968
# Epoch 3/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.1634 - accuracy: 0.5832 - val_loss: 1.1397 - val_accuracy: 0.5990
# Epoch 4/15
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.0770 - accuracy: 0.6163 - val_loss: 1.0045 - val_accuracy: 0.6409
# Epoch 5/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0007 - accuracy: 0.6445 - val_loss: 0.9415 - val_accuracy: 0.6686
# Epoch 6/15
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.9302 - accuracy: 0.6708 - val_loss: 0.9221 - val_accuracy: 0.6741
# Epoch 7/15
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.8752 - accuracy: 0.6898 - val_loss: 0.9183 - val_accuracy: 0.6763
# Epoch 8/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8304 - accuracy: 0.7069 - val_loss: 0.8613 - val_accuracy: 0.6948
# Epoch 9/15
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7914 - accuracy: 0.7199 - val_loss: 0.8460 - val_accuracy: 0.7038
# Epoch 10/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7547 - accuracy: 0.7342 - val_loss: 0.8394 - val_accuracy: 0.7103
# Epoch 11/15
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7281 - accuracy: 0.7414 - val_loss: 0.8211 - val_accuracy: 0.7141
# Epoch 12/15
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.6982 - accuracy: 0.7528 - val_loss: 0.8238 - val_accuracy: 0.7105
# Epoch 13/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6758 - accuracy: 0.7593 - val_loss: 0.8266 - val_accuracy: 0.7089
# Epoch 14/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6533 - accuracy: 0.7678 - val_loss: 0.8106 - val_accuracy: 0.7165
# Epoch 15/15
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.6320 - accuracy: 0.7757 - val_loss: 0.7994 - val_accuracy: 0.7205

# %% [markdown]
# ## Exibindo gráfico de perda e acurácia

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend()
plt.show()

# %% [markdown]
# ## Predição

# %%
y_pred = model.predict(x_test).argmax(axis=1)

cm = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(conf_mat=cm, figsize=(7,7), show_normed=True)
# Out:
# 313/313 [==============================] - 1s 2ms/step
# (<Figure size 700x700 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)

# %% [markdown]
# ## Classificações erradas

# %%
labels = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

misclassified = np.where(y_pred != y_test)[0]

i = np.random.choice(misclassified)

plt.imshow(x_test[i], cmap='gray')
plt.title("True label: %s Predicted: %s" % (labels[y_test[i]], labels[y_pred[i]]))
# Out:
# Text(0.5, 1.0, 'True label: dog Predicted: cat')
